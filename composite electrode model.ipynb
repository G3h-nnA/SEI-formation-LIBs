# %%
import pybamm as pb
import numpy as np
import matplotlib.pyplot as plt
from func_project import *

# %%
# fetch parameter values

Chen = pb.ParameterValues("Chen2020_composite")
ORegan = pb.ParameterValues("ORegan2022")

params = Chen.copy()

f = open("temp.txt", "w")
for param in Chen:
    try:
        if Chen[param] != ORegan[param]:
            print(f"For {param}, Chen2020 value:{Chen[param]} \tORegan2022 value: {ORegan[param]}\n")
            f.write(f"For {param}, Chen2020 value:{Chen[param]} \tORegan2022 value: {ORegan[param]}\n")
            params.update({param: ORegan[param]})
        else:
            print(f"Skipped. The values for ({param}) is the same for both...")
    except:
        print(f"There is no value for {param} in ORegan2022")
# Out:
# Skipped. The values for (Ideal gas constant [J.K-1.mol-1]) is the same for both...
# Skipped. The values for (Faraday constant [C.mol-1]) is the same for both...
# Skipped. The values for (Boltzmann constant [J.K-1]) is the same for both...
# Skipped. The values for (Electron charge [C]) is the same for both...
# There is no value for Primary: Ratio of lithium moles to SEI moles in ORegan2022
# There is no value for Primary: SEI partial molar volume [m3.mol-1] in ORegan2022
# There is no value for Primary: SEI reaction exchange current density [A.m-2] in ORegan2022
# There is no value for Primary: SEI resistivity [Ohm.m] in ORegan2022
# There is no value for Primary: SEI solvent diffusivity [m2.s-1] in ORegan2022
# There is no value for Primary: Bulk solvent concentration [mol.m-3] in ORegan2022
# There is no value for Primary: SEI open-circuit potential [V] in ORegan2022
# There is no value for Primary: SEI electron conductivity [S.m-1] in ORegan2022
# There is no value for Primary: SEI lithium interstitial diffusivity [m2.s-1] in ORegan2022
# There is no value for Primary: Lithium interstitial reference concentration [mol.m-3] in ORegan2022
# There is no value for Primary: Initial SEI thickness [m] in ORegan2022
# There is no value for Primary: EC initial concentration in electrolyte [mol.m-3] in ORegan2022
# There is no value for Primary: EC diffusivity [m2.s-1] in ORegan2022
# There is no value for Primary: SEI kinetic rate constant [m.s-1] in ORegan2022
# There is no value for Primary: SEI growth activation energy [J.mol-1] in ORegan2022
# There is no value for Secondary: Ratio of lithium moles to SEI moles in ORegan2022
# There is no value for Secondary: SEI partial molar volume [m3.mol-1] in ORegan2022
# There is no value for Secondary: SEI reaction exchange current density [A.m-2] in ORegan2022
# There is no value for Secondary: SEI resistivity [Ohm.m] in ORegan2022
# There is no value for Secondary: SEI solvent diffusivity [m2.s-1] in ORegan2022
# There is no value for Secondary: Bulk solvent concentration [mol.m-3] in ORegan2022
# There is no value for Secondary: SEI open-circuit potential [V] in ORegan2022
# There is no value for Secondary: SEI electron conductivity [S.m-1] in ORegan2022
# There is no value for Secondary: SEI lithium interstitial diffusivity [m2.s-1] in ORegan2022
# There is no value for Secondary: Lithium interstitial reference concentration [mol.m-3] in ORegan2022
# There is no value for Secondary: Initial SEI thickness [m] in ORegan2022
# There is no value for Secondary: EC initial concentration in electrolyte [mol.m-3] in ORegan2022
# There is no value for Secondary: EC diffusivity [m2.s-1] in ORegan2022
# There is no value for Secondary: SEI kinetic rate constant [m.s-1] in ORegan2022
# There is no value for Secondary: SEI growth activation energy [J.mol-1] in ORegan2022
# There is no value for Positive electrode reaction-driven LAM factor [m3.mol-1] in ORegan2022
# Skipped. The values for (Negative current collector thickness [m]) is the same for both...
# Skipped. The values for (Negative electrode thickness [m]) is the same for both...
# Skipped. The values for (Separator thickness [m]) is the same for both...
# Skipped. The values for (Positive electrode thickness [m]) is the same for both...
# Skipped. The values for (Positive current collector thickness [m]) is the same for both...
# Skipped. The values for (Electrode height [m]) is the same for both...
# Skipped. The values for (Electrode width [m]) is the same for both...
# Skipped. The values for (Cell cooling surface area [m2]) is the same for both...
# Skipped. The values for (Cell volume [m3]) is the same for both...
# There is no value for Cell thermal expansion coefficient [m.K-1] in ORegan2022
# Skipped. The values for (Negative current collector conductivity [S.m-1]) is the same for both...
# Skipped. The values for (Positive current collector conductivity [S.m-1]) is the same for both...
# For Negative current collector density [kg.m-3], Chen2020 value:8960.0 	ORegan2022 value: 8933.0
#
# For Positive current collector density [kg.m-3], Chen2020 value:2700.0 	ORegan2022 value: 2702.0
#
# For Negative current collector specific heat capacity [J.kg-1.K-1], Chen2020 value:385.0 	ORegan2022 value: <function copper_heat_capacity_CRC at 0x000002504C381A80>
#
# For Positive current collector specific heat capacity [J.kg-1.K-1], Chen2020 value:897.0 	ORegan2022 value: <function aluminium_heat_capacity_CRC at 0x000002504C381B20>
#
# For Negative current collector thermal conductivity [W.m-1.K-1], Chen2020 value:401.0 	ORegan2022 value: <function copper_thermal_conductivity_CRC at 0x000002504C381BC0>
#
# Skipped. The values for (Positive current collector thermal conductivity [W.m-1.K-1]) is the same for both...
# Skipped. The values for (Nominal cell capacity [A.h]) is the same for both...
# Skipped. The values for (Current function [A]) is the same for both...
# Skipped. The values for (Contact resistance [Ohm]) is the same for both...
# Skipped. The values for (Negative electrode conductivity [S.m-1]) is the same for both...
# There is no value for Primary: Maximum concentration in negative electrode [mol.m-3] in ORegan2022
# There is no value for Primary: Initial concentration in negative electrode [mol.m-3] in ORegan2022
# There is no value for Primary: Negative particle diffusivity [m2.s-1] in ORegan2022
# There is no value for Primary: Negative electrode OCP [V] in ORegan2022
# Skipped. The values for (Negative electrode porosity) is the same for both...
# There is no value for Primary: Negative electrode active material volume fraction in ORegan2022
# There is no value for Primary: Negative particle radius [m] in ORegan2022
# Skipped. The values for (Negative electrode Bruggeman coefficient (electrolyte)) is the same for both...
# Skipped. The values for (Negative electrode Bruggeman coefficient (electrode)) is the same for both...
# Skipped. The values for (Negative electrode charge transfer coefficient) is the same for both...
# Skipped. The values for (Negative electrode double-layer capacity [F.m-2]) is the same for both...
# There is no value for Primary: Negative electrode exchange-current density [A.m-2] in ORegan2022
# There is no value for Primary: Negative electrode density [kg.m-3] in ORegan2022
# For Negative electrode specific heat capacity [J.kg-1.K-1], Chen2020 value:700.0 	ORegan2022 value: <function graphite_LGM50_heat_capacity_ORegan2022 at 0x000002504C381E40>
#
# For Negative electrode thermal conductivity [W.m-1.K-1], Chen2020 value:1.7 	ORegan2022 value: <function graphite_LGM50_thermal_conductivity_ORegan2022 at 0x000002504C381EE0>
#
# There is no value for Primary: Negative electrode OCP entropic change [V.K-1] in ORegan2022
# There is no value for Secondary: Maximum concentration in negative electrode [mol.m-3] in ORegan2022
# There is no value for Secondary: Initial concentration in negative electrode [mol.m-3] in ORegan2022
# There is no value for Secondary: Negative particle diffusivity [m2.s-1] in ORegan2022
# There is no value for Secondary: Negative electrode lithiation OCP [V] in ORegan2022
# There is no value for Secondary: Negative electrode delithiation OCP [V] in ORegan2022
# There is no value for Secondary: Negative electrode OCP [V] in ORegan2022
# There is no value for Secondary: Negative electrode active material volume fraction in ORegan2022
# There is no value for Secondary: Negative particle radius [m] in ORegan2022
# There is no value for Secondary: Negative electrode exchange-current density [A.m-2] in ORegan2022
# There is no value for Secondary: Negative electrode density [kg.m-3] in ORegan2022
# There is no value for Secondary: Negative electrode OCP entropic change [V.K-1] in ORegan2022
# For Positive electrode conductivity [S.m-1], Chen2020 value:0.18 	ORegan2022 value: <function nmc_LGM50_electronic_conductivity_ORegan2022 at 0x000002504C382020>
#
# For Maximum concentration in positive electrode [mol.m-3], Chen2020 value:63104.0 	ORegan2022 value: 51765.0
#
# For Positive particle diffusivity [m2.s-1], Chen2020 value:4e-15 	ORegan2022 value: <function nmc_LGM50_diffusivity_ORegan2022 at 0x000002504C3820C0>
#
# For Positive electrode OCP [V], Chen2020 value:<function nmc_LGM50_ocp_Chen2020 at 0x000002504C380F40> 	ORegan2022 value: <function nmc_LGM50_ocp_Chen2020 at 0x000002504C382160>
#
# Skipped. The values for (Positive electrode porosity) is the same for both...
# Skipped. The values for (Positive electrode active material volume fraction) is the same for both...
# Skipped. The values for (Positive particle radius [m]) is the same for both...
# Skipped. The values for (Positive electrode Bruggeman coefficient (electrolyte)) is the same for both...
# Skipped. The values for (Positive electrode Bruggeman coefficient (electrode)) is the same for both...
# Skipped. The values for (Positive electrode charge transfer coefficient) is the same for both...
# Skipped. The values for (Positive electrode double-layer capacity [F.m-2]) is the same for both...
# For Positive electrode exchange-current density [A.m-2], Chen2020 value:<function nmc_LGM50_electrolyte_exchange_current_density_Chen2020 at 0x000002504C380FE0> 	ORegan2022 value: <function nmc_LGM50_electrolyte_exchange_current_density_ORegan2022 at 0x000002504C382200>
#
# For Positive electrode density [kg.m-3], Chen2020 value:3262.0 	ORegan2022 value: 3699.0
#
# For Positive electrode specific heat capacity [J.kg-1.K-1], Chen2020 value:700.0 	ORegan2022 value: <function nmc_LGM50_heat_capacity_ORegan2022 at 0x000002504C3822A0>
#
# For Positive electrode thermal conductivity [W.m-1.K-1], Chen2020 value:2.1 	ORegan2022 value: <function nmc_LGM50_thermal_conductivity_ORegan2022 at 0x000002504C382340>
#
# For Positive electrode OCP entropic change [V.K-1], Chen2020 value:0.0 	ORegan2022 value: <function nmc_LGM50_entropic_change_ORegan2022 at 0x000002504C3823E0>
#
# Skipped. The values for (Separator porosity) is the same for both...
# Skipped. The values for (Separator Bruggeman coefficient (electrolyte)) is the same for both...
# For Separator density [kg.m-3], Chen2020 value:397.0 	ORegan2022 value: 1548.0
#
# For Separator specific heat capacity [J.kg-1.K-1], Chen2020 value:700.0 	ORegan2022 value: <function separator_LGM50_heat_capacity_ORegan2022 at 0x000002504C382480>
#
# For Separator thermal conductivity [W.m-1.K-1], Chen2020 value:0.16 	ORegan2022 value: 0.3344
#
# Skipped. The values for (Initial concentration in electrolyte [mol.m-3]) is the same for both...
# For Cation transference number, Chen2020 value:0.2594 	ORegan2022 value: <function electrolyte_transference_number_EC_EMC_3_7_Landesfeind2019 at 0x000002504C382520>
#
# For Thermodynamic factor, Chen2020 value:1.0 	ORegan2022 value: <function electrolyte_TDF_EC_EMC_3_7_Landesfeind2019 at 0x000002504C3825C0>
#
# For Electrolyte diffusivity [m2.s-1], Chen2020 value:<function electrolyte_diffusivity_Nyman2008 at 0x000002504C381080> 	ORegan2022 value: <function electrolyte_diffusivity_EC_EMC_3_7_Landesfeind2019 at 0x000002504C382660>
#
# For Electrolyte conductivity [S.m-1], Chen2020 value:<function electrolyte_conductivity_Nyman2008 at 0x000002504C381120> 	ORegan2022 value: <function electrolyte_conductivity_EC_EMC_3_7_Landesfeind2019 at 0x000002504C382700>
#
# Skipped. The values for (Reference temperature [K]) is the same for both...
# Skipped. The values for (Total heat transfer coefficient [W.m-2.K-1]) is the same for both...
# Skipped. The values for (Ambient temperature [K]) is the same for both...
# Skipped. The values for (Number of electrodes connected in parallel to make a cell) is the same for both...
# Skipped. The values for (Number of cells connected in series to make a battery) is the same for both...
# Skipped. The values for (Lower voltage cut-off [V]) is the same for both...
# For Upper voltage cut-off [V], Chen2020 value:4.2 	ORegan2022 value: 4.4
#
# Skipped. The values for (Open-circuit voltage at 0% SOC [V]) is the same for both...
# For Open-circuit voltage at 100% SOC [V], Chen2020 value:4.2 	ORegan2022 value: 4.4
#
# For Initial concentration in negative electrode [mol.m-3], Chen2020 value:29866.0 	ORegan2022 value: 28866.0
#
# For Initial concentration in positive electrode [mol.m-3], Chen2020 value:17038.0 	ORegan2022 value: 13975.0
#
# Skipped. The values for (Initial temperature [K]) is the same for both...
# For citations, Chen2020 value:['Chen2020', 'Ai2022'] 	ORegan2022 value: ['ORegan2022', 'Chen2020']

# %%
"""
    Pre-simulation settings
"""
parameters = params.copy()

# Adding plating parameters to the parameter set

parameters.update(
    {
    
        # Parameters for primary/secondary phases in the composite
        'Primary: SEI lithium ion conductivity [S.m-1]': 1.0e-7,
        'Secondary: SEI lithium ion conductivity [S.m-1]': 1.0e-7,        
        "Primary: Tunneling distance for electrons [m]": 0,
        "Secondary: Tunneling distance for electrons [m]": 0,

        #"Primary: Initial inner SEI thickness [m]": 5e-09,
        #"Secondary: Initial inner SEI thickness [m]": 5e-09,
        #"Primary: Initial outer SEI thickness [m]": 5e-09,
        #"Secondary: Initial outer SEI thickness [m]": 5e-09,

        'Primary: Negative electrode density [kg.m-3]': 1657.0,
        'Secondary: Negative electrode density [kg.m-3]': 2650.0,

        #"Positive electrode OCP [V]": nmc_LGM50_ocp_Chen2020,
        "Negative electrode density [kg.m-3]": (0.9*1657 + 0.1*2560),

        "Primary: Maximum concentration in negative electrode [mol.m-3]": 28700,
        #"Primary: Initial concentration in negative electrode [mol.m-3]": 23000,
        #"Primary: Negative particle diffusivity [m2.s-1]": 5.5e-14,
        #"Secondary: Negative particle diffusivity [m2.s-1]": 1.67e-14,
        #"Secondary: Initial concentration in negative electrode [mol.m-3]": 275220,
        "Secondary: Maximum concentration in negative electrode [mol.m-3]": 278000,

        # particle radius
        #"Primary: Positive particle radius [m]": ,

    }, check_already_exists=False,
)


# write the parameter values and model variables to a text file
f = open("parameter_values.txt", "w")
f.write(f"{parameters}")
f.close()

# mesh settings
var_pts = {"x_n": 15, "x_s": 15, "x_p": 15, "r_n": 40, "r_p": 40}
submesh_types = pb.lithium_ion.DFN().default_submesh_types
submesh_types["negative particle"] = pb.MeshGenerator(
    pb.Exponential1DSubMesh, submesh_params={"side": "right"}
)
submesh_types["positive particle"] = pb.MeshGenerator(
    pb.Exponential1DSubMesh, submesh_params={"side": "right"}
)


# output variables that are of interest
output_variables = [
    "Throughput capacity [A.h]",
    "X-averaged negative total SEI thickness [m]",
    "Loss of capacity to negative SEI [A.h]",
    "Terminal voltage [V]",
    "Discharge capacity [A.h]",
    #"Electrolyte potential [V]",
    "X-averaged negative primary SEI thickness [m]"
]

# %%
# Defining the composite model
model = pb.lithium_ion.DFN(options={
        "particle phases": ("2", "1"),
        "open-circuit potential": (("single", "current sigmoid"), "single"),
        "SEI": "VonKolzenberg2020",
        "thermal": "lumped",
    
        "cell geometry": "arbitrary",
        "dimensionality": 0,
    }, name="VK_composite"
)

# write the readable outputs to a text file
f = open("output_vars.txt", "w")
for v in sorted(model.variable_names()):
    f.write(f"{v}\n")
f.close()

# %% [markdown]
# ### Temperature sweep

# %%
# C-rate settings, change for different C-rates
cycles = 5
C_rate = "0.5C" # ["2C", "1C", "C/2", "C/10"]

exp=pb.Experiment(
    [
        (
            f"Charge at {C_rate} until 4.2 V",
            "Rest for 1 hour",
            f"Discharge at {C_rate} until 2.5 V",
            "Rest for 1 hour",
        )
    ]* cycles
)


# add some variable parameters for the composite structure
params = parameters.copy()

# parametric sweep through different temperatures
temps = list(np.asarray([-10, 0, 25, 40]) + 273.15)

# updating the volume fraction of the composite phases
v_si = 0.12
total_am_volume_fraction = 0.75

params.update({
            "Primary: Negative electrode active material volume fraction": (1 - v_si)
            * total_am_volume_fraction,  # primary
            "Secondary: Negative electrode active material volume fraction": v_si
            * total_am_volume_fraction,
            "Primary: Maximum concentration in positive electrode [mol.m-3]": 51765.0,
}, check_already_exists=False)

# empty solution array
temp_sols = []

# loop through different temperatures
for temp in temps:
    # print experiment conditions
    params.update({"Ambient temperature [K]": temp, "Initial temperature [K]": temp})
    params.search("Ambient temperature [K]")
    params.search("Initial temperature [K]")
    print(f"Current experiment: {exp}\n C rate:{C_rate}\n Temperature: {temp - 273.15}$C")

    sim = pb.Simulation(
        model,
        parameter_values=params,
        experiment=exp,
        #var_pts=var_pts,
        submesh_types=submesh_types,
    )
    
    sol = sim.solve(calc_esoh=False)
    temp_sols.append(sol)
    
    # saving simulation data
    #sol.save(f"composite_VK_{C_rate}_{temp}K_{cycles}cycles.pkl")
# Out:
# Results for 'Ambient temperature [K]': ['Ambient temperature [K]']
# Ambient temperature [K] -> 263.15
# Results for 'Initial temperature [K]': ['Initial temperature [K]']
# Initial temperature [K] -> 263.15
# Current experiment: [('Charge at 0.5C until 4.2 V', 'Rest for 1 hour', 'Discharge at 0.5C until 2.5 V', 'Rest for 1 hour'), ('Charge at 0.5C until 4.2 V', 'Rest for 1 hour', 'Discharge at 0.5C until 2.5 V', 'Rest for 1 hour'), ('Charge at 0.5C until 4.2 V', 'Rest for 1 hour', 'Discharge at 0.5C until 2.5 V', 'Rest for 1 hour'), ('Charge at 0.5C until 4.2 V', 'Rest for 1 hour', 'Discharge at 0.5C until 2.5 V', 'Rest for 1 hour'), ('Charge at 0.5C until 4.2 V', 'Rest for 1 hour', 'Discharge at 0.5C until 2.5 V', 'Rest for 1 hour')]
#  C rate:0.5C
#  Temperature: -10.0$C
# Results for 'Ambient temperature [K]': ['Ambient temperature [K]']
# Ambient temperature [K] -> 273.15
# Results for 'Initial temperature [K]': ['Initial temperature [K]']
# Initial temperature [K] -> 273.15
# Current experiment: [('Charge at 0.5C until 4.2 V', 'Rest for 1 hour', 'Discharge at 0.5C until 2.5 V', 'Rest for 1 hour'), ('Charge at 0.5C until 4.2 V', 'Rest for 1 hour', 'Discharge at 0.5C until 2.5 V', 'Rest for 1 hour'), ('Charge at 0.5C until 4.2 V', 'Rest for 1 hour', 'Discharge at 0.5C until 2.5 V', 'Rest for 1 hour'), ('Charge at 0.5C until 4.2 V', 'Rest for 1 hour', 'Discharge at 0.5C until 2.5 V', 'Rest for 1 hour'), ('Charge at 0.5C until 4.2 V', 'Rest for 1 hour', 'Discharge at 0.5C until 2.5 V', 'Rest for 1 hour')]
#  C rate:0.5C
#  Temperature: 0.0$C
# Results for 'Ambient temperature [K]': ['Ambient temperature [K]']
# Ambient temperature [K] -> 298.15
# Results for 'Initial temperature [K]': ['Initial temperature [K]']
# Initial temperature [K] -> 298.15
# Current experiment: [('Charge at 0.5C until 4.2 V', 'Rest for 1 hour', 'Discharge at 0.5C until 2.5 V', 'Rest for 1 hour'), ('Charge at 0.5C until 4.2 V', 'Rest for 1 hour', 'Discharge at 0.5C until 2.5 V', 'Rest for 1 hour'), ('Charge at 0.5C until 4.2 V', 'Rest for 1 hour', 'Discharge at 0.5C until 2.5 V', 'Rest for 1 hour'), ('Charge at 0.5C until 4.2 V', 'Rest for 1 hour', 'Discharge at 0.5C until 2.5 V', 'Rest for 1 hour'), ('Charge at 0.5C until 4.2 V', 'Rest for 1 hour', 'Discharge at 0.5C until 2.5 V', 'Rest for 1 hour')]
#  C rate:0.5C
#  Temperature: 25.0$C
# Results for 'Ambient temperature [K]': ['Ambient temperature [K]']
# Ambient temperature [K] -> 313.15
# Results for 'Initial temperature [K]': ['Initial temperature [K]']
# Initial temperature [K] -> 313.15
# Current experiment: [('Charge at 0.5C until 4.2 V', 'Rest for 1 hour', 'Discharge at 0.5C until 2.5 V', 'Rest for 1 hour'), ('Charge at 0.5C until 4.2 V', 'Rest for 1 hour', 'Discharge at 0.5C until 2.5 V', 'Rest for 1 hour'), ('Charge at 0.5C until 4.2 V', 'Rest for 1 hour', 'Discharge at 0.5C until 2.5 V', 'Rest for 1 hour'), ('Charge at 0.5C until 4.2 V', 'Rest for 1 hour', 'Discharge at 0.5C until 2.5 V', 'Rest for 1 hour'), ('Charge at 0.5C until 4.2 V', 'Rest for 1 hour', 'Discharge at 0.5C until 2.5 V', 'Rest for 1 hour')]
#  C rate:0.5C
#  Temperature: 40.0$C

# %%
# plot results of temperature sweep
def plot_results(solution_set, variables):
    '''
    plot graph of SEI thickness, Capacity loss and Voltage against total throughput

        solution_set = list of solutions after solving multiple models
        variables = variables changed during parametric sweep
    
    '''
    fig, axes = plt.subplots(3,2, layout="constrained", figsize=(10,12), gridspec_kw={"hspace": 0.1}, sharex=False)
    plt.ticklabel_format(style="sci", axis="y", scilimits=(0,0))

    for index, sol in enumerate(solution_set):
        # independent variable
        Q_tot = sol["Throughput capacity [A.h]"].entries
        t = sol["Time [h]"].entries

        # various dependent variables
        Q_SEI = sol["Loss of capacity to negative SEI [A.h]"].entries
        Q_SEI_1 = sol["Loss of capacity to negative primary SEI [A.h]"].entries
        Q_SEI_2 = sol["Loss of capacity to negative secondary SEI [A.h]"].entries

        # current densities
        J_SEI_1 = sol["X-averaged negative electrode primary SEI interfacial current density [A.m-2]"].entries
        J_SEI_2 = sol["X-averaged negative electrode secondary SEI interfacial current density [A.m-2]"].entries
        J_SEI = (J_SEI_1 + J_SEI_2)
        

        V_i = sol["Voltage [V]"].entries
        # electrolyte_V = sol["Electrolyte potential [V]"].entries
        # C_dis = sol["Discharge capacity [A.h]"].entries
        
        # LLI
        Q_LLI = sol["Total lithium lost [mol]"].entries #*96485.3 / 3600
        
        # SEI thickness of composite phases
        L_SEI_1 = (sol["X-averaged negative total primary SEI thickness [m]"].entries)*1e9
        L_SEI_2 = (sol["X-averaged negative total secondary SEI thickness [m]"].entries)*1e9
        L_SEI = (L_SEI_1 + L_SEI_2)
        L_min = np.min(L_SEI)
        delta_L = (L_SEI - L_min)

        # plot graph on the go

        axes[0][0].plot(Q_tot, Q_SEI, label=f"{variables[index]}", linestyle="--")
        axes[0][1].plot(Q_tot, J_SEI, label=f"{variables[index]}", linestyle="--")
        axes[1][0].plot(Q_tot, L_SEI, label=f"{variables[index]}", linestyle="--")
        axes[1][1].plot(t, delta_L, label=f"{variables[index]}", linestyle="--")
        axes[2][0].plot(t, V_i, label=f"{variables[index]}", linestyle="--")
        axes[2][1].plot(Q_tot, Q_LLI, label=f"{variables[index]}", linestyle="--")
        
    # graph formatting
    # Primary on the left, secondary on the right?
    axes[0][0].set_xlabel("Total throughput capacity [A.h]")
    axes[0][0].set_ylabel("Loss of capacity to negative SEI [A.h]") 
    axes[0][0].legend()
    
    axes[0][1].set_xlabel("Total throughput capacity [A.h]")
    axes[0][1].set_ylabel("SEI interfacial current density [A.m-2]")

    axes[1][0].set_xlabel("Total throughput capacity [A.h]")
    axes[1][0].set_ylabel("Total SEI thickness (Primary/Secondary) [nm]")


    axes[1][1].set_xlabel("Time [h]")
    axes[1][1].set_ylabel("Net SEI growth [nm]")

    axes[2][0].set_xlabel("Total throughput capacity [A.h]")
    axes[2][0].set_ylabel("Voltage [V]")

    axes[2][1].set_xlabel("Total throughput capacity [A.h]")
    axes[2][1].set_ylabel("Loss of lithium inventory [A.h]")


temps = list(np.asarray([-10, 0, 25, 40]) + 273.15)
labels = ["-10$^o$C", "0$^o$C", "25$^o$C", "40$^o$C"]
print(f"labels: {labels}")

plot_results(temp_sols, labels)
# Out:
# labels: ['-10$^o$C', '0$^o$C', '25$^o$C', '40$^o$C']
